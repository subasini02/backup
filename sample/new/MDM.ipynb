# %%
! pip install pandas fuzzywuzzy python-levenshtein recordlinkage numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\subasini\appdata\roaming\python\python311\site-packages (2.2.2)
# Requirement already satisfied: fuzzywuzzy in c:\users\subasini\appdata\roaming\python\python311\site-packages (0.18.0)
# Collecting python-levenshtein
#   Obtaining dependency information for python-levenshtein from https://files.pythonhosted.org/packages/72/8e/559c539e76bc0b1defec3da39a047fe151258efc9b215bf41db41e2c7922/python_Levenshtein-0.25.1-py3-none-any.whl.metadata
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting recordlinkage
#   Obtaining dependency information for recordlinkage from https://files.pythonhosted.org/packages/12/fc/05c343d0b8e02c1b2f45256202a50f6970dae0bfac791c569a74c779c76d/recordlinkage-0.16-py3-none-any.whl.metadata
#   Downloading recordlinkage-0.16-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy in c:\users\subasini\appdata\roaming\python\python311\site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Collecting Levenshtein==0.25.1 (from python-levenshtein)
#   Obtaining dependency information for Levenshtein==0.25.1 from https://files.pythonhosted.org/packages/47/19/4528246e25bb79fa8d4adae6640251c613f05eb310d79307d1ac53c7bf28/Levenshtein-0.25.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading Levenshtein-0.25.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from Levenshtein==0.25.1->python-levenshtein) (3.9.0)
# Collecting jellyfish>=1 (from recordlinkage)
#   Obtaining dependency information for jellyfish>=1 from https://files.pythonhosted.org/packages/7e/25/9fc8c0836ecddcdb0acd2abbf0ecf334d9425afbe1099b61ecdde981669c/jellyfish-1.0.3-cp311-none-win_amd64.whl.metadata
#   Downloading jellyfish-1.0.3-cp311-none-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: scipy>=1 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from recordlinkage) (1.13.0)
# Requirement already satisfied: scikit-learn>=1 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from recordlinkage) (1.4.2)
# Requirement already satisfied: joblib in c:\users\subasini\appdata\roaming\python\python311\site-packages (from recordlinkage) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\subasini\appdata\roaming\python\python311\site-packages (from scikit-learn>=1->recordlinkage) (3.5.0)
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp311-cp311-win_amd64.whl (98 kB)
#    ---------------------------------------- 0.0/98.4 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/98.4 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/98.4 kB ? eta -:--:--
#    ---------------------------------------- 98.4/98.4 kB 801.1 kB/s eta 0:00:00
# Downloading recordlinkage-0.16-py3-none-any.whl (926 kB)
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    - -------------------------------------- 30.7/926.9 kB ? eta -:--:--
#    - -------------------------------------- 30.7/926.9 kB ? eta -:--:--
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 112.6/926.9 kB 1.1 MB/s eta 0:00:01
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    ----- -------------------------------- 122.9/926.9 kB 206.3 kB/s eta 0:00:04
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    -------- ----------------------------- 204.8/926.9 kB 178.0 kB/s eta 0:00:05
#    ------------- ------------------------ 317.4/926.9 kB 213.8 kB/s eta 0:00:03
#    ------------- ------------------------ 317.4/926.9 kB 213.8 kB/s eta 0:00:03
#    -------------- ----------------------- 358.4/926.9 kB 227.4 kB/s eta 0:00:03
#    -------------- ----------------------- 358.4/926.9 kB 227.4 kB/s eta 0:00:03
#    ----------------- -------------------- 419.8/926.9 kB 249.8 kB/s eta 0:00:03
#    ------------------ ------------------- 440.3/926.9 kB 259.7 kB/s eta 0:00:02
#    ------------------ ------------------- 440.3/926.9 kB 259.7 kB/s eta 0:00:02
#    ------------------ ------------------- 440.3/926.9 kB 259.7 kB/s eta 0:00:02
#    ------------------ ------------------- 440.3/926.9 kB 259.7 kB/s eta 0:00:02
#    ------------------ ------------------- 440.3/926.9 kB 259.7 kB/s eta 0:00:02
#    ------------------- ------------------ 481.3/926.9 kB 247.1 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    -------------------- ----------------- 501.8/926.9 kB 251.7 kB/s eta 0:00:02
#    --------------------- ---------------- 522.2/926.9 kB 229.2 kB/s eta 0:00:02
#    ---------------------- --------------- 553.0/926.9 kB 237.9 kB/s eta 0:00:02
#    ---------------------- --------------- 553.0/926.9 kB 237.9 kB/s eta 0:00:02
#    ----------------------- -------------- 563.2/926.9 kB 234.4 kB/s eta 0:00:02
#    ----------------------- -------------- 583.7/926.9 kB 236.9 kB/s eta 0:00:02
#    ------------------------ ------------- 604.2/926.9 kB 242.1 kB/s eta 0:00:02
#    -------------------------- ----------- 634.9/926.9 kB 249.9 kB/s eta 0:00:02
#    ---------------------------- --------- 686.1/926.9 kB 265.5 kB/s eta 0:00:01
#    ---------------------------- --------- 696.3/926.9 kB 266.1 kB/s eta 0:00:01
#    ---------------------------- --------- 696.3/926.9 kB 266.1 kB/s eta 0:00:01
#    ---------------------------- --------- 696.3/926.9 kB 266.1 kB/s eta 0:00:01
#    ----------------------------- -------- 727.0/926.9 kB 263.7 kB/s eta 0:00:01
#    ------------------------------ ------- 747.5/926.9 kB 266.6 kB/s eta 0:00:01
#    ------------------------------ ------- 747.5/926.9 kB 266.6 kB/s eta 0:00:01
#    ------------------------------ ------- 747.5/926.9 kB 266.6 kB/s eta 0:00:01
#    ------------------------------- ------ 778.2/926.9 kB 261.5 kB/s eta 0:00:01
#    -------------------------------- ----- 798.7/926.9 kB 264.2 kB/s eta 0:00:01
#    -------------------------------- ----- 798.7/926.9 kB 264.2 kB/s eta 0:00:01
#    -------------------------------- ----- 798.7/926.9 kB 264.2 kB/s eta 0:00:01
#    -------------------------------- ----- 798.7/926.9 kB 264.2 kB/s eta 0:00:01
#    --------------------------------- ---- 809.0/926.9 kB 254.4 kB/s eta 0:00:01
#    ---------------------------------- --- 829.4/926.9 kB 255.8 kB/s eta 0:00:01
#    ---------------------------------- --- 849.9/926.9 kB 258.4 kB/s eta 0:00:01
#    ----------------------------------- -- 860.2/926.9 kB 257.9 kB/s eta 0:00:01
#    ------------------------------------ - 880.6/926.9 kB 260.4 kB/s eta 0:00:01
#    -------------------------------------  911.4/926.9 kB 264.6 kB/s eta 0:00:01
#    -------------------------------------- 926.9/926.9 kB 266.7 kB/s eta 0:00:00
# Downloading jellyfish-1.0.3-cp311-none-win_amd64.whl (210 kB)
#    ---------------------------------------- 0.0/210.9 kB ? eta -:--:--
#    --- ------------------------------------ 20.5/210.9 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/210.9 kB 991.0 kB/s eta 0:00:01
#    ------- ------------------------------- 41.0/210.9 kB 991.0 kB/s eta 0:00:01
#    ------- ------------------------------- 41.0/210.9 kB 991.0 kB/s eta 0:00:01
#    ------------- ------------------------- 71.7/210.9 kB 326.8 kB/s eta 0:00:01
#    ----------------- --------------------- 92.2/210.9 kB 374.1 kB/s eta 0:00:01
#    ----------------- --------------------- 92.2/210.9 kB 374.1 kB/s eta 0:00:01
#    ----------------- --------------------- 92.2/210.9 kB 374.1 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/210.9 kB 288.1 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/210.9 kB 288.1 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/210.9 kB 288.1 kB/s eta 0:00:01
#    ---------------------- --------------- 122.9/210.9 kB 288.1 kB/s eta 0:00:01
#    ----------------------- -------------- 133.1/210.9 kB 231.4 kB/s eta 0:00:01
#    ----------------------- -------------- 133.1/210.9 kB 231.4 kB/s eta 0:00:01
#    ----------------------- -------------- 133.1/210.9 kB 231.4 kB/s eta 0:00:01
#    ----------------------- -------------- 133.1/210.9 kB 231.4 kB/s eta 0:00:01
#    --------------------------- ---------- 153.6/210.9 kB 191.1 kB/s eta 0:00:01
#    --------------------------- ---------- 153.6/210.9 kB 191.1 kB/s eta 0:00:01
#    --------------------------- ---------- 153.6/210.9 kB 191.1 kB/s eta 0:00:01
#    --------------------------- ---------- 153.6/210.9 kB 191.1 kB/s eta 0:00:01
#    --------------------------- ---------- 153.6/210.9 kB 191.1 kB/s eta 0:00:01
#    ------------------------------- ------ 174.1/210.9 kB 166.3 kB/s eta 0:00:01
#    ------------------------------- ------ 174.1/210.9 kB 166.3 kB/s eta 0:00:01
#    --------------------------------- ---- 184.3/210.9 kB 163.8 kB/s eta 0:00:01
#    --------------------------------- ---- 184.3/210.9 kB 163.8 kB/s eta 0:00:01
#    ----------------------------------- -- 194.6/210.9 kB 161.5 kB/s eta 0:00:01
#    ------------------------------------ - 204.8/210.9 kB 159.6 kB/s eta 0:00:01
#    -------------------------------------- 210.9/210.9 kB 162.5 kB/s eta 0:00:00
# Installing collected packages: Levenshtein, jellyfish, python-levenshtein, recordlinkage
# Successfully installed Levenshtein-0.25.1 jellyfish-1.0.3 python-levenshtein-0.25.1 recordlinkage-0.16

# %%
import pandas as pd
import recordlinkage
from recordlinkage.preprocessing import clean
from metaphone import doublemetaphone

# Load the data from CSV
df = pd.read_csv('./new.csv')

# Clean the data (optional step)
df['aggr_full_name'] = clean(df['aggr_full_name'])
df['full_name'] = clean(df['full_name'])

print("DataFrame:\n", df)

# Apply phonetic encoding for blocking
df['aggr_full_name_soundex'] = df['aggr_full_name'].apply(lambda x: doublemetaphone(x)[0])
df['full_name_soundex'] = df['full_name'].apply(lambda x: doublemetaphone(x)[0])

print("DataFrame with Soundex:\n", df)

# Create indexer to identify potential matches
indexer = recordlinkage.Index()
indexer.block('aggr_full_name_soundex')
candidate_links = indexer.index(df)

print("Candidate Links:\n", candidate_links)

# Compare records using Jaro-Winkler similarity
compare_cl = recordlinkage.Compare()
compare_cl.string('aggr_full_name', 'full_name', method='jarowinkler', threshold=0.75, label='name')

# Compute similarity features
features = compare_cl.compute(candidate_links, df)
print("Similarity Features:\n", features)

# Sum the similarity scores for name
features['score'] = features.sum(axis=1)
print("Features with Combined Score:\n", features)

# Define a threshold for automatic confirmation
threshold = 0.2  # Adjust based on your data and requirements
confirmed_matches = features[features['score'] >= threshold]
print("Confirmed Matches:\n", confirmed_matches)

# Reset index to ensure uniqueness
df.reset_index(drop=True, inplace=True)
confirmed_matches.reset_index(drop=True, inplace=True)

# Extract matched records
matched_records = []
for match_index in confirmed_matches.index:
    left_idx, right_idx = confirmed_matches.loc[match_index]
    matched_records.append([df.loc[left_idx, 'full_name'], df.loc[right_idx, 'aggr_full_name']])

# Create DataFrame from matched records
matched_df = pd.DataFrame(matched_records, columns=['full_name', 'aggr_full_name'])

# Display the matched DataFrame with only 'full_name' and 'aggr_full_name'
print("Matched DataFrame:\n", matched_df)
# Out:
# DataFrame:
#                                       loc_id         loc_name  \
# 0      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 1      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 2      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 3      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 4      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# ...                                     ...              ...
# 11758  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11759  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11760  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11761  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
# 11762  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
#
#       aggr_order_channel aggr_full_name aggr_soundex_score channel  \
# 0               UberEats     abhishek s               A120  Maghil
# 1               UberEats     abhishek s               A120  Maghil
# 2               UberEats     abhishek s               A120  Maghil
# 3               UberEats     abhishek s               A120  Maghil
# 4               UberEats     abhishek s               A120  Maghil
# ...                  ...            ...                ...     ...
# 11758           UberEats       venkat r              V5236  Maghil
# 11759           UberEats       venkat r              V5236  Maghil
# 11760           UberEats       venkat r              V5236  Maghil
# 11761          Uber eats          bagya               B200  Maghil
# 11762          Uber eats          bagya               B200  Maghil
#
#               full_name magil_soundex_score  maghil_phone match_score  \
# 0              abhishek                A120   -6292439194         Low
# 1               abhisek                A120   -9736416575         Low
# 2        abhishek chaki                A120   -6462484858         Low
# 3              abhishek                A120   -2012204715         Low
# 4              abhishek                A120   -9734243785         Low
# ...                 ...                 ...           ...         ...
# 11758          venkat l               V5234   -6464310310         Low
# 11759  venkata munnangi              V52352   -7323227146         Low
# 11760      venkatvenkat            V5231523   -7328619848         Low
# 11761             bagya                B200   -7327607938        High
# 11762             bagya                B200   -3127527095        High
#
#          first_name last_name agg_first_name agg_last_name  sim_sco_full_name  \
# 0          abhishek       NaN       abhishek            s.                 84
# 1           abhisek       NaN       abhishek            s.                 78
# 2          abhishek     chaki       abhishek            s.                 72
# 3          abhishek       NaN       abhishek            s.                 84
# 4          abhishek       NaN       abhishek            s.                 84
# ...             ...       ...            ...           ...                ...
# 11758        venkat         l         venkat            r.                 82
# 11759       venkata  munnangi         venkat            r.                 56
# 11760  venkatvenkat       NaN         venkat            r.                 57
# 11761         bagya       NaN          bagya           NaN                 91
# 11762         bagya       NaN          bagya           NaN                100
#
#        sim_sco_first_name  sim_sco_last_name
# 0                     100                  0
# 1                      93                  0
# 2                     100                  0
# 3                     100                  0
# 4                     100                  0
# ...                   ...                ...
# 11758                 100                  0
# 11759                  92                  0
# 11760                  67                  0
# 11761                 100                100
# 11762                 100                100
#
# [11763 rows x 17 columns]
# DataFrame with Soundex:
#                                       loc_id         loc_name  \
# 0      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 1      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 2      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 3      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 4      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# ...                                     ...              ...
# 11758  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11759  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11760  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11761  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
# 11762  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
#
#       aggr_order_channel aggr_full_name aggr_soundex_score channel  \
# 0               UberEats     abhishek s               A120  Maghil
# 1               UberEats     abhishek s               A120  Maghil
# 2               UberEats     abhishek s               A120  Maghil
# 3               UberEats     abhishek s               A120  Maghil
# 4               UberEats     abhishek s               A120  Maghil
# ...                  ...            ...                ...     ...
# 11758           UberEats       venkat r              V5236  Maghil
# 11759           UberEats       venkat r              V5236  Maghil
# 11760           UberEats       venkat r              V5236  Maghil
# 11761          Uber eats          bagya               B200  Maghil
# 11762          Uber eats          bagya               B200  Maghil
#
#               full_name magil_soundex_score  maghil_phone match_score  \
# 0              abhishek                A120   -6292439194         Low
# 1               abhisek                A120   -9736416575         Low
# 2        abhishek chaki                A120   -6462484858         Low
# 3              abhishek                A120   -2012204715         Low
# 4              abhishek                A120   -9734243785         Low
# ...                 ...                 ...           ...         ...
# 11758          venkat l               V5234   -6464310310         Low
# 11759  venkata munnangi              V52352   -7323227146         Low
# 11760      venkatvenkat            V5231523   -7328619848         Low
# 11761             bagya                B200   -7327607938        High
# 11762             bagya                B200   -3127527095        High
#
#          first_name last_name agg_first_name agg_last_name  sim_sco_full_name  \
# 0          abhishek       NaN       abhishek            s.                 84
# 1           abhisek       NaN       abhishek            s.                 78
# 2          abhishek     chaki       abhishek            s.                 72
# 3          abhishek       NaN       abhishek            s.                 84
# 4          abhishek       NaN       abhishek            s.                 84
# ...             ...       ...            ...           ...                ...
# 11758        venkat         l         venkat            r.                 82
# 11759       venkata  munnangi         venkat            r.                 56
# 11760  venkatvenkat       NaN         venkat            r.                 57
# 11761         bagya       NaN          bagya           NaN                 91
# 11762         bagya       NaN          bagya           NaN                100
#
#        sim_sco_first_name  sim_sco_last_name aggr_full_name_soundex  \
# 0                     100                  0                  APXKS
# 1                      93                  0                  APXKS
# 2                     100                  0                  APXKS
# 3                     100                  0                  APXKS
# 4                     100                  0                  APXKS
# ...                   ...                ...                    ...
# 11758                 100                  0                  FNKTR
# 11759                  92                  0                  FNKTR
# 11760                  67                  0                  FNKTR
# 11761                 100                100                     PK
# 11762                 100                100                     PK
#
#       full_name_soundex
# 0                  APXK
# 1                  APSK
# 2                APXKXK
# 3                  APXK
# 4                  APXK
# ...                 ...
# 11758             FNKTL
# 11759          FNKTMNNJ
# 11760          FNKTFNKT
# 11761                PK
# 11762                PK
#
# [11763 rows x 19 columns]
# Candidate Links:
#  MultiIndex([(    1,     0),
#             (    2,     0),
#             (    2,     1),
#             (    3,     0),
#             (    3,     1),
#             (    3,     2),
#             (    4,     0),
#             (    4,     1),
#             (    4,     2),
#             (    4,     3),
#             ...
#             (11760, 11751),
#             (11760, 11752),
#             (11760, 11753),
#             (11760, 11754),
#             (11760, 11755),
#             (11760, 11756),
#             (11760, 11757),
#             (11760, 11758),
#             (11760, 11759),
#             (11762, 11761)],
#            length=1058411)
# Similarity Features:
#               name
# 1     0       1.0
# 2     0       1.0
#       1       1.0
# 3     0       1.0
#       1       1.0
# ...           ...
# 11760 11756   1.0
#       11757   1.0
#       11758   1.0
#       11759   1.0
# 11762 11761   1.0
#
# [1058411 rows x 1 columns]
# Features with Combined Score:
#               name  score
# 1     0       1.0    1.0
# 2     0       1.0    1.0
#       1       1.0    1.0
# 3     0       1.0    1.0
#       1       1.0    1.0
# ...           ...    ...
# 11760 11756   1.0    1.0
#       11757   1.0    1.0
#       11758   1.0    1.0
#       11759   1.0    1.0
# 11762 11761   1.0    1.0
#
# [1058411 rows x 2 columns]
# Confirmed Matches:
#               name  score
# 1     0       1.0    1.0
# 2     0       1.0    1.0
#       1       1.0    1.0
# 3     0       1.0    1.0
#       1       1.0    1.0
# ...           ...    ...
# 11760 11756   1.0    1.0
#       11757   1.0    1.0
#       11758   1.0    1.0
#       11759   1.0    1.0
# 11762 11761   1.0    1.0
#
# [1032512 rows x 2 columns]
# Matched DataFrame:
#          full_name aggr_full_name
# 0         abhisek     abhishek s
# 1         abhisek     abhishek s
# 2         abhisek     abhishek s
# 3         abhisek     abhishek s
# 4         abhisek     abhishek s
# ...           ...            ...
# 1032507   abhisek     abhishek s
# 1032508   abhisek     abhishek s
# 1032509   abhisek     abhishek s
# 1032510   abhisek     abhishek s
# 1032511   abhisek     abhishek s
#
# [1032512 rows x 2 columns]

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from metaphone import doublemetaphone

# Load the data from CSV
df = pd.read_csv('./new.csv')

# Clean the data (optional step)
df['aggr_full_name'] = df['aggr_full_name'].apply(lambda x: x.lower())
df['full_name'] = df['full_name'].apply(lambda x: x.lower())

print("DataFrame:\n", df)

# Apply phonetic encoding for blocking
df['aggr_full_name_soundex'] = df['aggr_full_name'].apply(lambda x: doublemetaphone(x)[0])
df['full_name_soundex'] = df['full_name'].apply(lambda x: doublemetaphone(x)[0])

print("DataFrame with Soundex:\n", df)

# Define a function to compute string similarity using fuzzywuzzy
def compute_similarity(row):
    return fuzz.partial_ratio(row['aggr_full_name'], row['full_name'])

# Compute similarity between pairs of records
df['similarity_score'] = df.apply(compute_similarity, axis=1)

# Define a threshold for potential matches
threshold = 75  # Adjust based on your data and requirements
potential_matches = df[df['similarity_score'] >= threshold]

print("Potential Matches:\n", potential_matches[['full_name', 'aggr_full_name']])
# Out:
# DataFrame:
#                                       loc_id         loc_name  \
# 0      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 1      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 2      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 3      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 4      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# ...                                     ...              ...
# 11758  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11759  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11760  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11761  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
# 11762  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
#
#       aggr_order_channel aggr_full_name aggr_soundex_score channel  \
# 0               UberEats    abhishek s.               A120  Maghil
# 1               UberEats    abhishek s.               A120  Maghil
# 2               UberEats    abhishek s.               A120  Maghil
# 3               UberEats    abhishek s.               A120  Maghil
# 4               UberEats    abhishek s.               A120  Maghil
# ...                  ...            ...                ...     ...
# 11758           UberEats      venkat r.              V5236  Maghil
# 11759           UberEats      venkat r.              V5236  Maghil
# 11760           UberEats      venkat r.              V5236  Maghil
# 11761          Uber eats          bagya               B200  Maghil
# 11762          Uber eats          bagya               B200  Maghil
#
#               full_name magil_soundex_score  maghil_phone match_score  \
# 0              abhishek                A120   -6292439194         Low
# 1               abhisek                A120   -9736416575         Low
# 2        abhishek chaki                A120   -6462484858         Low
# 3              abhishek                A120   -2012204715         Low
# 4              abhishek                A120   -9734243785         Low
# ...                 ...                 ...           ...         ...
# 11758          venkat l               V5234   -6464310310         Low
# 11759  venkata munnangi              V52352   -7323227146         Low
# 11760      venkatvenkat            V5231523   -7328619848         Low
# 11761            bagya                 B200   -7327607938        High
# 11762             bagya                B200   -3127527095        High
#
#          first_name last_name agg_first_name agg_last_name  sim_sco_full_name  \
# 0          abhishek       NaN       abhishek            s.                 84
# 1           abhisek       NaN       abhishek            s.                 78
# 2          abhishek     chaki       abhishek            s.                 72
# 3          abhishek       NaN       abhishek            s.                 84
# 4          abhishek       NaN       abhishek            s.                 84
# ...             ...       ...            ...           ...                ...
# 11758        venkat         l         venkat            r.                 82
# 11759       venkata  munnangi         venkat            r.                 56
# 11760  venkatvenkat       NaN         venkat            r.                 57
# 11761         bagya       NaN          bagya           NaN                 91
# 11762         bagya       NaN          bagya           NaN                100
#
#        sim_sco_first_name  sim_sco_last_name
# 0                     100                  0
# 1                      93                  0
# 2                     100                  0
# 3                     100                  0
# 4                     100                  0
# ...                   ...                ...
# 11758                 100                  0
# 11759                  92                  0
# 11760                  67                  0
# 11761                 100                100
# 11762                 100                100
#
# [11763 rows x 17 columns]
# DataFrame with Soundex:
#                                       loc_id         loc_name  \
# 0      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 1      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 2      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 3      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# 4      14d293a8-81c5-40b2-a208-be1c03a93fad   A2B Parsippany
# ...                                     ...              ...
# 11758  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11759  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11760  7e2a8a81-1462-11eb-89a4-42010a010003          A2B SPF
# 11761  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
# 11762  88cc107b-bc75-4d1a-9b35-9199e69d3b3d  A2B Warrenville
#
#       aggr_order_channel aggr_full_name aggr_soundex_score channel  \
# 0               UberEats    abhishek s.               A120  Maghil
# 1               UberEats    abhishek s.               A120  Maghil
# 2               UberEats    abhishek s.               A120  Maghil
# 3               UberEats    abhishek s.               A120  Maghil
# 4               UberEats    abhishek s.               A120  Maghil
# ...                  ...            ...                ...     ...
# 11758           UberEats      venkat r.              V5236  Maghil
# 11759           UberEats      venkat r.              V5236  Maghil
# 11760           UberEats      venkat r.              V5236  Maghil
# 11761          Uber eats          bagya               B200  Maghil
# 11762          Uber eats          bagya               B200  Maghil
#
#               full_name magil_soundex_score  maghil_phone match_score  \
# 0              abhishek                A120   -6292439194         Low
# 1               abhisek                A120   -9736416575         Low
# 2        abhishek chaki                A120   -6462484858         Low
# 3              abhishek                A120   -2012204715         Low
# 4              abhishek                A120   -9734243785         Low
# ...                 ...                 ...           ...         ...
# 11758          venkat l               V5234   -6464310310         Low
# 11759  venkata munnangi              V52352   -7323227146         Low
# 11760      venkatvenkat            V5231523   -7328619848         Low
# 11761            bagya                 B200   -7327607938        High
# 11762             bagya                B200   -3127527095        High
#
#          first_name last_name agg_first_name agg_last_name  sim_sco_full_name  \
# 0          abhishek       NaN       abhishek            s.                 84
# 1           abhisek       NaN       abhishek            s.                 78
# 2          abhishek     chaki       abhishek            s.                 72
# 3          abhishek       NaN       abhishek            s.                 84
# 4          abhishek       NaN       abhishek            s.                 84
# ...             ...       ...            ...           ...                ...
# 11758        venkat         l         venkat            r.                 82
# 11759       venkata  munnangi         venkat            r.                 56
# 11760  venkatvenkat       NaN         venkat            r.                 57
# 11761         bagya       NaN          bagya           NaN                 91
# 11762         bagya       NaN          bagya           NaN                100
#
#        sim_sco_first_name  sim_sco_last_name aggr_full_name_soundex  \
# 0                     100                  0                 APXKSS
# 1                      93                  0                 APXKSS
# 2                     100                  0                 APXKSS
# 3                     100                  0                 APXKSS
# 4                     100                  0                 APXKSS
# ...                   ...                ...                    ...
# 11758                 100                  0                 FNKTRR
# 11759                  92                  0                 FNKTRR
# 11760                  67                  0                 FNKTRR
# 11761                 100                100                     PK
# 11762                 100                100                     PK
#
#       full_name_soundex
# 0                  APXK
# 1                  APSK
# 2                APXKXK
# 3                  APXK
# 4                  APXK
# ...                 ...
# 11758             FNKTL
# 11759          FNKTMNNJ
# 11760          FNKTFNKT
# 11761                PK
# 11762                PK
#
# [11763 rows x 19 columns]
# Potential Matches:
#                full_name aggr_full_name
# 0              abhishek    abhishek s.
# 1               abhisek    abhishek s.
# 2        abhishek chaki    abhishek s.
# 3              abhishek    abhishek s.
# 4              abhishek    abhishek s.
# ...                 ...            ...
# 11757            venkat      venkat r.
# 11758          venkat l      venkat r.
# 11759  venkata munnangi      venkat r.
# 11761            bagya           bagya
# 11762             bagya          bagya
#
# [10108 rows x 2 columns]

# %%
import pandas as pd
import recordlinkage

# Load the CSV file
data = pd.read_csv('./new3.csv')

# Assume you have 'Name' and 'OtherName' columns for comparison
name_column = 'full_name'
other_name_column = 'aggr_full_name'

# Indexing the dataset
indexer = recordlinkage.Index()
indexer.full()
pairs = indexer.index(data)

# Comparing records
compare = recordlinkage.Compare()

compare.string(name_column, other_name_column, method='jarowinkler', threshold=0.85)

features = compare.compute(pairs, data)

# Blocking
matches = features[features.sum(axis=1) > 0]

print(matches)
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.
#          0
# 12 5   1.0
# 15 5   1.0
# 43 12  1.0
#    15  1.0
# 49 21  1.0
# 50 21  1.0
# 52 21  1.0

# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('./new3.csv')

# Define the matches with their similarity scores
matches = [
    (8, 7, 1.0), (9, 5, 1.0), (12, 5, 1.0), (15, 5, 1.0), (9, 15, 1.0), (21, 5, 1.0), (9, 21, 1.0), (40, 9, 1.0),
    (21, 40, 1.0), (43, 9, 1.0), (12, 43, 1.0), (15, 43, 1.0), (21, 43, 1.0), (12, 15, 1.0), (12, 21, 1.0),
    (46, 45, 1.0), (49, 21, 1.0), (50, 21, 1.0), (52, 5, 1.0), (12, 52, 1.0), (15, 52, 1.0), (21, 52, 1.0),
    (40, 52, 1.0), (43, 52, 1.0), (49, 52, 1.0), (50, 52, 1.0), (55, 5, 1.0), (12, 55, 1.0), (15, 55, 1.0),
    (21, 55, 1.0), (40, 55, 1.0), (43, 55, 1.0), (49, 55, 1.0), (50, 55, 1.0), (57, 21, 1.0), (59, 12, 1.0),
    (15, 59, 1.0), (21, 59, 1.0), (49, 59, 1.0), (50, 59, 1.0), (68, 67, 1.0), (75, 5, 1.0), (21, 75, 1.0),
    (40, 75, 1.0), (43, 75, 1.0), (79, 62, 1.0), (80, 62, 1.0), (85, 5, 1.0), (21, 85, 1.0), (40, 85, 1.0),
    (43, 85, 1.0), (87, 75, 1.0), (88, 62, 1.0), (90, 75, 1.0)
]

# Print corresponding full_name and aggr_full_name along with similarity score
for match in matches:
    index1, index2, similarity_score = match
    print("Index 1:", index1)
    print("Full Name 1:", data.loc[index1, 'full_name'])
    print("Index 2:", index2)
    print("Aggr Full Name 2:", data.loc[index2, 'aggr_full_name'])
    print("Similarity Score:", similarity_score)
    print()
# Out:
# Index 1: 8
# Full Name 1: vignesh subbarorangapashyam
# Index 2: 7
# Aggr Full Name 2: vignesh v
# Similarity Score: 1.0
#
# Index 1: 9
# Full Name 1: venkat subramanian
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 15
# Full Name 1: venkateswaran venkatramani
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 9
# Full Name 1: venkat subramanian
# Index 2: 15
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 9
# Full Name 1: venkat subramanian
# Index 2: 21
# Aggr Full Name 2: venkat r.
# Similarity Score: 1.0
#
# Index 1: 40
# Full Name 1: venky dw
# Index 2: 9
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 40
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 43
# Full Name 1: venkata gadamsetty
# Index 2: 9
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 43
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 15
# Full Name 1: venkateswaran venkatramani
# Index 2: 43
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 43
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 15
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 21
# Aggr Full Name 2: venkat r.
# Similarity Score: 1.0
#
# Index 1: 46
# Full Name 1: pratyush trivedi
# Index 2: 45
# Aggr Full Name 2: pratik r
# Similarity Score: 1.0
#
# Index 1: 49
# Full Name 1: venkat krishnan
# Index 2: 21
# Aggr Full Name 2: venkat r.
# Similarity Score: 1.0
#
# Index 1: 50
# Full Name 1: venkat krishnan
# Index 2: 21
# Aggr Full Name 2: venkat r.
# Similarity Score: 1.0
#
# Index 1: 52
# Full Name 1: venkatesh srinivasan
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 15
# Full Name 1: venkateswaran venkatramani
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 40
# Full Name 1: venky dw
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 43
# Full Name 1: venkata gadamsetty
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 49
# Full Name 1: venkat krishnan
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 50
# Full Name 1: venkat krishnan
# Index 2: 52
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 55
# Full Name 1: venkatesan kannamari
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 12
# Full Name 1: venkatesh kunduru
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 15
# Full Name 1: venkateswaran venkatramani
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 40
# Full Name 1: venky dw
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 43
# Full Name 1: venkata gadamsetty
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 49
# Full Name 1: venkat krishnan
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 50
# Full Name 1: venkat krishnan
# Index 2: 55
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 57
# Full Name 1: venkatraman nagaraja
# Index 2: 21
# Aggr Full Name 2: venkat r.
# Similarity Score: 1.0
#
# Index 1: 59
# Full Name 1: venkataramana dingar
# Index 2: 12
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 15
# Full Name 1: venkateswaran venkatramani
# Index 2: 59
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 59
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 49
# Full Name 1: venkat krishnan
# Index 2: 59
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 50
# Full Name 1: venkat krishnan
# Index 2: 59
# Aggr Full Name 2: venkat we ez t
# Similarity Score: 1.0
#
# Index 1: 68
# Full Name 1: arundhati vattikola
# Index 2: 67
# Aggr Full Name 2: arun d
# Similarity Score: 1.0
#
# Index 1: 75
# Full Name 1: venkatesh munukutla
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 75
# Aggr Full Name 2: venkata sravya k.
# Similarity Score: 1.0
#
# Index 1: 40
# Full Name 1: venky dw
# Index 2: 75
# Aggr Full Name 2: venkata sravya k.
# Similarity Score: 1.0
#
# Index 1: 43
# Full Name 1: venkata gadamsetty
# Index 2: 75
# Aggr Full Name 2: venkata sravya k.
# Similarity Score: 1.0
#
# Index 1: 79
# Full Name 1: srinu velichety
# Index 2: 62
# Aggr Full Name 2: srinivasala y.
# Similarity Score: 1.0
#
# Index 1: 80
# Full Name 1: srinu velichety
# Index 2: 62
# Aggr Full Name 2: srinivasala y.
# Similarity Score: 1.0
#
# Index 1: 85
# Full Name 1: venkatesh munukutla
# Index 2: 5
# Aggr Full Name 2: venkateswarlu e
# Similarity Score: 1.0
#
# Index 1: 21
# Full Name 1: venkateshvenkatexh
# Index 2: 85
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 40
# Full Name 1: venky dw
# Index 2: 85
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 43
# Full Name 1: venkata gadamsetty
# Index 2: 85
# Aggr Full Name 2: venkata sai teja r.
# Similarity Score: 1.0
#
# Index 1: 87
# Full Name 1: venkatakrishnan hariharan
# Index 2: 75
# Aggr Full Name 2: venkata sravya k.
# Similarity Score: 1.0
#
# Index 1: 88
# Full Name 1: srinu velichety
# Index 2: 62
# Aggr Full Name 2: srinivasala y.
# Similarity Score: 1.0
#
# Index 1: 90
# Full Name 1: venkiteswaran vaidyanathan
# Index 2: 75
# Aggr Full Name 2: venkata sravya k.
# Similarity Score: 1.0
